# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('general_data.csv')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# # Check for Nulls

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeID                  0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %% [markdown]
# # Drop Null Values

# %%
df.dropna(inplace=True)

# %% [markdown]
# # Drop Duplicates

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4405    False
# 4406    False
# 4407    False
# 4408    False
# 4409    False
# Length: 4410, dtype: bool

# %%
df.drop_duplicates(inplace=True)

# %%
df.var()
# Out:
# Age                        8.348974e+01
# DistanceFromHome           6.569744e+01
# Education                  1.050068e+00
# EmployeeCount              0.000000e+00
# EmployeeID                 1.617192e+06
# JobLevel                   1.223490e+00
# MonthlyIncome              2.222397e+09
# NumCompaniesWorked         6.239165e+00
# PercentSalaryHike          1.341762e+01
# StandardHours              0.000000e+00
# StockOptionLevel           7.265814e-01
# TotalWorkingYears          6.061739e+01
# TrainingTimesLastYear      1.662558e+00
# YearsAtCompany             3.756894e+01
# YearsSinceLastPromotion    1.040059e+01
# YearsWithCurrManager       1.274257e+01
# dtype: float64

# %%
df.skew()
# Out:
# Age                        0.413048
# DistanceFromHome           0.955517
# Education                 -0.288977
# EmployeeCount              0.000000
# EmployeeID                -0.002335
# JobLevel                   1.021797
# MonthlyIncome              1.367457
# NumCompaniesWorked         1.029174
# PercentSalaryHike          0.819510
# StandardHours              0.000000
# StockOptionLevel           0.967263
# TotalWorkingYears          1.115419
# TrainingTimesLastYear      0.551818
# YearsAtCompany             1.764619
# YearsSinceLastPromotion    1.980992
# YearsWithCurrManager       0.834277
# dtype: float64

# %%
df.kurt()
# Out:
# Age                       -0.409517
# DistanceFromHome          -0.230691
# Education                 -0.565008
# EmployeeCount              0.000000
# EmployeeID                -1.198607
# JobLevel                   0.388189
# MonthlyIncome              0.990836
# NumCompaniesWorked         0.014307
# PercentSalaryHike         -0.306951
# StandardHours              0.000000
# StockOptionLevel           0.356755
# TotalWorkingYears          0.909316
# TrainingTimesLastYear      0.494215
# YearsAtCompany             3.930726
# YearsSinceLastPromotion    3.592162
# YearsWithCurrManager       0.170703
# dtype: float64

# %%
plt.boxplot(df.Age)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x213e4958588>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x213e4945cc8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x213e4945348>],
#  'medians': [<matplotlib.lines.Line2D at 0x213e4948fc8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x213e4979988>],
#  'means': []}

# %%
plt.boxplot(df.YearsAtCompany)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x213e48156c8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x213e481cec8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x213e481c348>],
#  'medians': [<matplotlib.lines.Line2D at 0x213e4822c48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x213e4822d88>],
#  'means': []}

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# C:\Users\abhij\anaconda3\lib\site-packages\pandas\io\formats\style.py:1089: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(s.to_numpy()) if vmin is None else vmin
# C:\Users\abhij\anaconda3\lib\site-packages\pandas\io\formats\style.py:1090: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# <style  type="text/css" >
#     #T_0cfc04b6_c9d9_11ea_8a9c_d037458ee996row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0cfc04b6_c9d9_11ea_8a9c_d037458ee996row0_col1 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_0cfc04b6_c9d9_11ea_8a9c_d037458ee996row0_col2 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_0cfc04b6_c9d9_11ea_8a9c_d037458ee996row0_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
# ...

# %%
plt.matshow(df.corr())
plt.show()

# %% [markdown]
# # Hypothesis
#
# Hypothesis 1:
# The average age of the employees stay in more than or equal to 32
#
# Null Hypothesis H0: μ>=32
#
# Alternative Hypothesis H1: μ<32
#
# Hypothesis 2:
# The average Monthly Income of an employee is equal to 65061.70
#
# Null Hypothesis H0: μ<=65061.7
#
# Alternative Hypothesis H1: μ> 65061.7
#
# Hypothesis 3:
# The male employee having high Monthly Income than fremale employee
#
# Null Hypothesis Ho : μa > μb
#
# Alternative Hypothesis H1 : μa < μb
#
# Hypothesis 4:
# The average years of the employees since last promotion who has left the company is less than 2 years
#
# Null Hypothesis H0: μ<=2
#
# Alternavtive Hypothesis H1: μ>2
#
# Hypothesis 5:
# The average number of years of an employee change frequently is less than 2
#
# Null Hypothesis H0 : μ<= 2
#
# Alternative Hypothesis H1: μ>2
#
# Hypothesis 6:
# The employee who works in Research & Development Department have high attrition rate than who works in Sales Department.
#
# Null Hypothesis H0: μa >= μb
#
# Alternative Hypothesis H1 : μa < μb
#
# Hypothesis 7:
# The average education of employees who stay in the company are having bachelor's degree level 3
#
# Null Hypothesis H0: μ = 3
#
# Alternative Hypothesis H1: μ != 3
#
# Hypothesis 8:
# The average training time of employees who left company is less 2 years
#
# Null Hypothesis H0: μ <= 2
#
# Alternative Hypothesis H1: μ > 2
#
# Hypothesis 9:
# The average employee having joblevel is less than or equal 2 years having high attrition rate
#
# Null Hypothesis H0: μ <= 2
#
# Alternative Hypothesis H1: μ > 2
#
# Hypothesis 10:
# The employee having Stack option level less than or equal to 1 having attrition rate
#
# Null Hypothesis H0: μ<=1
#
# Alternative Hypothesis H1: μ > 1
